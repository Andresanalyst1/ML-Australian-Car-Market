# %% [markdown]
# # Data Preprocessing
#  This file preprocesses the raw data extracted from Facebook Marketplace. It includes data cleaning, column analysis, value extraction, null value analysis, and related steps.

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd 
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Reading the csv file

# %%
df = pd.read_csv("data/raw_data_facebook_scraper.csv")
df.head()
# Out:
#                  id                              primary_listing_photo  \
# 0   842325545077316  {'image': {'uri': 'https://scontent.fsyd4-2.fn...
# 1  1282138740755042  {'image': {'uri': 'https://scontent.fsyd4-2.fn...
# 2  4343086952677152  {'image': {'uri': 'https://scontent.fsyd4-1.fn...
# 3   856599473632809  {'image': {'uri': 'https://scontent.fsyd4-1.fn...
# 4  1929741430912801  {'image': {'uri': 'https://scontent.fsyd4-1.fn...
#
#    if_gk_just_listed_tag_on_search_feed  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                        listing_price  \
# 0  {'formatted_amount': 'AU$11,300', 'amount_with...
# 1  {'formatted_amount': 'AU$5,000', 'amount_with_...
# 2  {'formatted_amount': 'AU$13,500', 'amount_with...
# 3  {'formatted_amount': 'AU$89,999', 'amount_with...
# ...

# %% [markdown]
# ## Removing Null Columns
#
# - To improve data quality, we dropped the columns that had **100% missing values** (all `NaN`).
# - These columns do not contribute any useful information to the model and only increase dataset size and complexity.

# %%
#checking cols that have all null values in it
all_null_cols_mask = df.isnull().all()
cols_with_all_nulls = df.columns[all_null_cols_mask].tolist()
print(cols_with_all_nulls)
df.drop(cols_with_all_nulls,axis=1,inplace=True)
# Out:
# ['if_gk_just_listed_tag_on_search_feed', 'comparable_price', 'comparable_price_type', 'min_listing_price', 'max_listing_price', 'origin_group', 'listing_video', 'parent_listing', 'marketplace_listing_seller', 'product_feedback', 'story', 'payment_time_period', 'marketplace_lead_gen_form', 'seller_message_thread', 'default_variant_listing', 'reportable_seller_type', 'active_order', 'rebuy_order_receipt', 'most_recent_active_order_as_buyer', 'shipping_profile', 'vacation_mode', 'incentive_campaign_for_free_shipping', 'first_message_suggested_value', 'sweepstake_content', 'marketplace_bump_info', 'fair_market_value_data', 'vehicle_identification_number', 'vehicle_registration_plate_information', 'vehicle_carfax_report', 'legal_disclosure_impressum_url', 'vehicle_website_link', 'seller', 'energy_efficiency_class_eu']

# %%
null_counts = df.isnull().sum()
percentage = 0.5
columns_with_many_nulls = null_counts[null_counts > len(df)*percentage].index.tolist()
print(columns_with_many_nulls)
# Out:
# ['strikethrough_price', 'inventory_count', 'legal_reporting_cta_type', 'legal_reporting_uri', 'seller_cms', 'vehicle_condition', 'vehicle_is_paid_off', 'vehicle_number_of_owners', 'vehicle_title_status', 'vehicle_trim_display_name', 'listing_address', 'seller_phone_number', 'dealership_name']

# %% [markdown]
# ## 1. Dropped Columns
#
# ### 1.1 Low Variance (Near-Constant Features)
# These columns contain almost the same value across the dataset (the most frequent value appears in more than **11,000 out of 11,955 rows**), providing little to no predictive power.
#
# - `condition`
#
#
#
# ### 1.2 URLs, Media, and Link-Only Columns
# These columns only store URLs or media references and do not provide numerical or categorical information useful for price prediction.
#
# - `listing_photos`
# - `listing_url`
# - `input_url`
# - `share_uri`
#
#
#
# ### 1.3 Duplicate or Redundant Information
# These columns duplicate information already captured in other features, making them unnecessary.
#
# - `custom_title` (covered by `listing_title`)
# - `location` (duplicate of `location_text`)
# - `custom_sub_titles_with_rendering_flags`
#
#
#
# ### 1.4 System-Generated or Unique Identifiers
# These columns contain IDs or system-level metadata that are unique per listing and do not contribute to learning price patterns.
#
# - `reportable_ent_id`
# - `primary_mp_ent`
# - `logging_id`
# - `location_vanity_or_id`
#
#
#
# ### 1.5 Not Relevant for Price Prediction
# These columns describe visibility settings, listing status, or platform-specific metadata that do not influence vehicle price.
#
# - `viewer_is_buyer`
# - `commerce_badges_info`
# - `cross_post_info`
# - `hidden_from_friends`
# - `is_hidden`
# - `is_live`
# - `is_pending`
# - `is_sold`,
# - `is_viewer_seller`
# - `marketplace_listing_category_id`
# - `delivery_types`
# - `attribute_data`
# - `origin_target`
# - `shipping_offered`
# - `pre_recorded_videos`
# - `vehicle_seller_type`
#
#
#
# ### 1.6 Mostly Empty or Uninformative Features
# These columns contain mostly empty values (e.g., empty lists) or lack meaningful structure.
#
# - `vehicle_features`
# - `product_item`
# - `creation_time`
# - `listing_inventory_type`
# - `messaging_enabled`
# - `listing_is_rejected`
# - `is_checkout_enabled`
# - `is_draft`
# - `can_seller_edit`
# - `can_share`
# - `can_seller_change_availability`
# - `is_on_marketplace`
# - `messagingEnabled`
# - `has_children`
# - `c2c_shipping_eligible`
# - `is_shipping_offered`
# - `order_summaries`
# - `should_hide_pdp_shipping_content`
# - `is_seller_business_onboarded`
# - `is_buy_now_enabled`
# - `is_purchase_protected`
# - `can_buyer_make_checkout_offer`
# - `is_cart_enabled`
# - `all_message_threads`
# - `should_show_txn_survey_on_mas`
# - `sweepstake_enabled`
# - `sweepstake_status`
# - `fi_enhanced_appeal_data`
# - `listing_seller_notices`
# - `is_email_communication_enabled`
#
#
#
# ### 1.7 High Missing Values
# These columns contain **more than 6,000 missing values** (over 50% of the dataset), making them unreliable for modeling.
#
# - `vehicle_number_of_owners`
# - `strikethrough_price`
# - `inventory_count`
# - `legal_reporting_cta_type`
# - `legal_reporting_uri`
# - `seller_cms`
# - `vehicle_condition`
# - `vehicle_is_paid_off`
# - `vehicle_title_status`
# - `vehicle_trim_display_name`
# - `listing_address`
# - `seller_phone_number`
# - `dealership_name`

# %%
cols_to_remove = ['strikethrough_price', 'inventory_count', 'legal_reporting_cta_type', 
        'legal_reporting_uri', 'seller_cms', 'vehicle_condition', 'vehicle_is_paid_off', 
        'vehicle_number_of_owners', 'vehicle_title_status', 'vehicle_trim_display_name', 
        'listing_address', 'seller_phone_number', 'dealership_name', 'id', 'primary_listing_photo',
        'is_hidden', 'is_live', 'is_pending', 'is_sold','is_viewer_seller', 'marketplace_listing_category_id',
       'delivery_types',"listing_photos","commerce_badges_info","custom_title","listingUrl","inputUrl",
        "if_viewer_is_buyer","vehicle_features","location","location_vanity_or_id","product_item",
        "cross_post_info","hidden_from_friends","reportable_ent_id",
        "primary_mp_ent","logging_id","share_uri",
        "custom_sub_titles_with_rendering_flags","vehicle_number_of_owners","condition", 'creation_time', 
        'listing_inventory_type', 'messaging_enabled', 'listing_is_rejected',
       'is_checkout_enabled', 'is_draft', 'can_seller_edit', 'can_share',
       'can_seller_change_availability', 'is_on_marketplace',
       'messagingEnabled', 'has_children', 'c2c_shipping_eligible',
       'is_shipping_offered', 'order_summaries',
       'should_hide_pdp_shipping_content', 'is_seller_business_onboarded',
       'is_buy_now_enabled', 'is_purchase_protected',
       'can_buyer_make_checkout_offer', 'is_cart_enabled',
       'all_message_threads', 'should_show_txn_survey_on_mas',
       'sweepstake_enabled', 'sweepstake_status', 'fi_enhanced_appeal_data',
       'listing_seller_notices', 'is_email_communication_enabled','attribute_data',
       'origin_target', 'shipping_offered', 'pre_recorded_videos','vehicle_seller_type']

df.drop(cols_to_remove,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['listing_price', 'marketplace_listing_title', 'redacted_description',
#        'location_text', 'formatted_price', 'vehicle_exterior_color',
#        'vehicle_fuel_type', 'vehicle_interior_color',
#        'vehicle_make_display_name', 'vehicle_model_display_name',
#        'vehicle_odometer_data', 'vehicle_specifications',
#        'vehicle_transmission_type'],
#       dtype='object')

# %%
df.tail(7)
# Out:
#                                            listing_price  \
# 11948  {'amount_with_offset': '2900000', 'currency': ...
# 11949  {'amount_with_offset': '2799900', 'currency': ...
# 11950  {'amount_with_offset': '590000', 'currency': '...
# 11951  {'amount_with_offset': '2495000', 'currency': ...
# 11952  {'amount_with_offset': '899000', 'currency': '...
# 11953  {'amount_with_offset': '1000', 'currency': 'AU...
# 11954  {'amount_with_offset': '950000', 'currency': '...
#
#                                marketplace_listing_title  \
# 11948                                    2020 Volvo XC60
# 11949            2019 Ford RANGER WILDTRAK PX MKlll AUTO
# 11950                           2002 Mercedes-Benz Sedan
# 11951                                2021 Nissan Qashqai
# 11952  2013 Hyundai 2013 Hyundai ix35 LM3 Elite Wagon...
# 11953                          2024 Mercedes-Benz GLA250
# 11954                             2015 Mitsubishi Lancer
#
# ...

# %% [markdown]
# ## Dropping Duplicate Price Column
#
# We dropped `formatted_price` because it contained some incorrect values (especially in the offset) and it was also a duplicate of `listing_price`.
# Since both columns represent the same information, we kept **`listing_price`** as the main price column.

# %%
print(df["listing_price"].isnull().sum())
df['listing_price'].value_counts
# Out:
# 0
# <bound method IndexOpsMixin.value_counts of 0        {'formatted_amount': 'AU$11,300', 'amount_with...
# 1        {'formatted_amount': 'AU$5,000', 'amount_with_...
# 2        {'formatted_amount': 'AU$13,500', 'amount_with...
# 3        {'formatted_amount': 'AU$89,999', 'amount_with...
# 4        {'formatted_amount': 'AU$18,800', 'amount_with...
# 5        {'formatted_amount': 'AU$40,000', 'amount_with...
# 6        {'formatted_amount': 'AU$40,000', 'amount_with...
# 7        {'formatted_amount': 'AU$26,500', 'amount_with...
# 8        {'formatted_amount': 'AU$36,880', 'amount_with...
# 9        {'formatted_amount': 'AU$13,500', 'amount_with...
# 10       {'formatted_amount': 'AU$31,999', 'amount_with...
# 11       {'formatted_amount': 'AU$8,800', 'amount_with_...
# 12       {'formatted_amount': 'AU$3,800', 'amount_with_...
# 13       {'formatted_amount': 'AU$15,999', 'amount_with...
# 14       {'formatted_amount': 'AU$13,000', 'amount_with...
# ...

# %%
df["formatted_price"].isnull().sum()
# Out:
# 114

# %%
df.drop("listing_price",axis=1,inplace=True)

# %%
df.tail()
# Out:
#                                marketplace_listing_title  \
# 11950                           2002 Mercedes-Benz Sedan
# 11951                                2021 Nissan Qashqai
# 11952  2013 Hyundai 2013 Hyundai ix35 LM3 Elite Wagon...
# 11953                          2024 Mercedes-Benz GLA250
# 11954                             2015 Mitsubishi Lancer
#
#                                     redacted_description  \
# 11950  {'text': 'Mercedes Benz kompressor classic sed...
# 11951  {'text': '2021 Nissan Qashqui Ti For Sale\nOne...
# 11952  {'text': "Will not respond to is this availabl...
# 11953  {'text': 'ALL CAR PARTS FOR SALE \nMelbourne C...
# 11954  {'text': 'Clean, reliable, and fuel-efficient....
#
#                     location_text        formatted_price  \
# 11950    {'text': 'Adelaide, SA'}   {'text': 'AU$5,900'}
# 11951  {'text': 'Melbourne, VIC'}  {'text': 'AU$24,950'}
# 11952  {'text': 'Melbourne, VIC'}   {'text': 'AU$8,990'}
# ...

# %% [markdown]
# ## 2. Dictionary Column Extraction

# %%
df["dist"] = df["vehicle_odometer_data"].astype(str).str[10:20]
df["dist"].value_counts()
# Out:
# dist
# KILOMETERS    11820
#                 114
# one, 'valu       17
# MILES', 'v        4
# Name: count, dtype: int64

# %% [markdown]
# ### 2.1 Extracting Distance in KM from `vehicle_odometer_data`
#
# - The `vehicle_odometer_data` column contained dictionary-like text values such as:
#
# `{'unit': 'KILOMETERS', 'value': 181000}`
#
# ### Step 1: Extracting the Unit
# We created a new column `dist` to identify the unit (mainly `KILOMETERS` and a few `MILES`) and checked the distribution using `value_counts()`.
#
# ### Step 2: Extracting the Odometer Value
# For rows where the unit was **KILOMETERS**, we extracted the numeric `value` using regex and stored it in a new column `distance_in_km`.
# We used the `Int64` datatype to safely handle missing values (`NaN`).
#
# ### Note on MILES and Noisy Values
# A very small number of rows contained the unit as **MILES**, and the remaining non-standard values were extremely few.
# Since their count was negligible compared to the dataset size, we ignored them to keep the data clean and consistent.
#
# ### Final Step: Dropping Temporary Columns
# After extracting the distance feature, we dropped the columns:
# - `vehicle_odometer_data`
# - `dist`

# %%
mask = df["dist"] == "KILOMETERS"

df.loc[mask, "kms"] = (
    df.loc[mask, "vehicle_odometer_data"]
      .astype(str)
      .str.extract(r"'value'\s*:\s*(\d+)", expand=False)
      .astype("Int64")
)
df[["vehicle_odometer_data","kms"]].tail(15)
# Out:
#                          vehicle_odometer_data     kms
# 11940  {'unit': 'KILOMETERS', 'value': 245930}  245930
# 11941   {'unit': 'KILOMETERS', 'value': 75003}   75003
# 11942   {'unit': 'KILOMETERS', 'value': 60000}   60000
# 11943  {'unit': 'KILOMETERS', 'value': 116348}  116348
# 11944   {'unit': 'KILOMETERS', 'value': 75000}   75000
# 11945   {'unit': 'KILOMETERS', 'value': 96000}   96000
# 11946  {'unit': 'KILOMETERS', 'value': 245000}  245000
# 11947  {'unit': 'KILOMETERS', 'value': 166000}  166000
# 11948   {'unit': 'KILOMETERS', 'value': 99500}   99500
# 11949  {'unit': 'KILOMETERS', 'value': 247000}  247000
# 11950  {'unit': 'KILOMETERS', 'value': 181000}  181000
# 11951   {'unit': 'KILOMETERS', 'value': 67502}   67502
# 11952  {'unit': 'KILOMETERS', 'value': 232045}  232045
# 11953   {'unit': 'KILOMETERS', 'value': 14000}   14000
# 11954  {'unit': 'KILOMETERS', 'value': 252433}  252433

# %%
col = ["vehicle_odometer_data","dist"]
df.drop(col,axis=1,inplace=True)

# %% [markdown]
# #### 2.2 Cleaning `formatted_price`
#
# The `formatted_price` column had values like `{'text': 'AU$5,900'}`.
# We created `price_currency` to check the currency types and found `AU$`, some `A$1/A$2...` (same currency), and `FRE` (means **FREE**).
#
# Since all `AU$`/`A$` represent Australian Dollars, we ignored currency and extracted only the numeric price value into `price_in_Dollars`.
# `FRE` entries were not used because they have no valid price.
#
# Finally, we dropped the columns:
# - `formatted_price`
# - `price_currency`

# %%
df["price_currency"] = df["formatted_price"].astype(str).str[10:13]
df["price_currency"].value_counts()
# Out:
# price_currency
# AU$    11782
#          114
# FRE       19
# A$1       16
# A$2       10
# A$9        3
# A$8        3
# A$5        3
# A$3        3
# A$7        2
# Name: count, dtype: int64

# %%
df["price"] = (
    df["formatted_price"]
    .astype(str)
    .str.extract(r"(\d[\d,]*)", expand=False) 
    .str.replace(",", "", regex=False)
    .astype("Int64")
)
df[["price_currency","formatted_price"]][df["price_currency"]=="FRE"].head()
# Out:
#      price_currency   formatted_price
# 413             FRE  {'text': 'FREE'}
# 595             FRE  {'text': 'FREE'}
# 742             FRE  {'text': 'FREE'}
# 1399            FRE  {'text': 'FREE'}
# 1984            FRE  {'text': 'FREE'}

# %%
cols = ["formatted_price","price_currency"]
df.drop(cols,axis=1,inplace=True)

# %% [markdown]
# #### 2.3 Extracting State from `location_text`
#
# The `location_text` column contained values like `{'text': 'Melbourne, VIC`}`.
# We extracted one new feature from it:
#
# - `state` → state code (e.g., VIC, NSW, QLD)
#
# After extraction, we used `value_counts()` on `state` to check the distribution across different states.

# %%
df["location_text"] = df["location_text"].astype(str)
df["state"] = df["location_text"].str.extract(r",\s*([A-Z]{2,3})'", expand=False).str.strip()

# %%
df["state"].value_counts()
# Out:
# state
# VIC    2727
# QLD    2434
# NSW    2305
# WA     2217
# SA     2151
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4  Extracting Year
# #### Extracting the manufacturing year from the column "marketplace_listing_title"

# %%
df["year"] = df["marketplace_listing_title"].str.lstrip().str[:4]
year = df["year"].value_counts().tail(30)

sns.barplot(x=year.index, y=year.values)
plt.xticks(rotation=90)
plt.show()

# %%
#According to the graph above there are just few minor 'years' which has different values (strings).
#Let's check it out

df[df["marketplace_listing_title"].str.startswith(("Mits","hyun","MG","Toyo","Hyun"), na=False)]

# After reviewing the data, these rows contain missing kilometer values and extreme price outliers, 
# so they will be removed.

mask1 = df["marketplace_listing_title"].str.startswith(("Mits","hyun","MG","Toyo","Hyun"), na=False)

df = df[~mask1]

# %%
#Checking dtype of year column
df["year"]=df["year"].astype("int")
#checking again plotbars
df["year"].info()
year = df["year"].value_counts().tail(30)
sns.barplot(x=year.index, y=year.values)
plt.xticks(rotation=90)
plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 11950 entries, 0 to 11954
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 11950 non-null  int32
# dtypes: int32(1)
# memory usage: 140.0 KB

# %% [markdown]
# ## 2.5 Dropping More Columns
#
# - Dropped `location_text` after extracting  `state`, since it was no longer needed.
#
# - Dropped `redacted_description` because it contains user-written descriptions with inconsistent detail (some rows have long descriptions, while many contain very little information like *"good car"* or *"negotiable"*), making it unreliable for modeling.
#
# - Dropped `vehicle_specifications` because most of its key-value pairs were `null`, and only a small number of rows had useful values like horsepower/engine size, so it was not effective for prediction.
#
# - Dropped `price currency` since is the same currency (Australian dollars) for the whole dataset.

# %%
cols = ["location_text","redacted_description","vehicle_specifications"]
df.drop(cols,axis=1,inplace=True)

# %%
df.tail(21)
# Out:
#                                marketplace_listing_title  \
# 11934                                  2017 Toyota Camry
# 11935  2010 Subaru forester Awd,reg&rwc auto Extended...
# 11936              2015 Mercedes-Benz Mercedes-Benz C230
# 11937                         2012 Mazda CX-5 Maxx Sport
# 11938                              1975 Volkswagen Kombi
# 11939                      2013 Toyota Landcruiser Prado
# 11940                                 1998 Nissan Pulsar
# 11941  2013 HSV Maloo GEN-F MY14 R8 Utility Extended ...
# 11942                       2019 Mercedes-Benz cla-class
# 11943      2011 Toyota estima - 20th anniversary edition
# 11944                                        2022 BMW X3
# 11945                                2019 Hyundai Tucson
# 11946                                 2008 Nissan Patrol
# 11947                  2015 Volkswagen Polo GTI RWC+REGO
# 11948                                    2020 Volvo XC60
# ...

# %% [markdown]
# ## 3. Analizing different Columns and null values

# %% [markdown]
# #### 3.1 "Vehicle_interior_color"

# %%
top_int_colors = df["vehicle_interior_color"].value_counts(normalize=True) * 100

print(top_int_colors)
#Due to Vehicle interior has not much variability (black color with more than 65%)
#Vehicle interior will be dropped from the dataset

df.drop("vehicle_interior_color",axis=1,inplace=True)
# Out:
# vehicle_interior_color
# black        66.821994
# grey         21.176349
# beige         2.329916
# blue          1.470436
# brown         1.397950
# white         1.346174
# red           1.273687
# charcoal      1.045873
# tan           0.973387
# off_white     0.724863
# silver        0.414207
# green         0.238169
# gold          0.196748
# orange        0.144973
# burgundy      0.103552
# other         0.093197
# yellow        0.082841
# purple        0.072486
# pink          0.062131
# turquoise     0.031066
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11950 entries, 0 to 11954
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   marketplace_listing_title   11950 non-null  object
#  1   vehicle_exterior_color      11724 non-null  object
#  2   vehicle_fuel_type           10424 non-null  object
#  3   vehicle_make_display_name   11836 non-null  object
#  4   vehicle_model_display_name  11447 non-null  object
#  5   vehicle_transmission_type   11822 non-null  object
#  6   kms                         11801 non-null  Int64
#  7   price                       11817 non-null  Int64
#  8   state                       11829 non-null  object
#  9   year                        11950 non-null  int32
# dtypes: Int64(2), int32(1), object(7)
# memory usage: 1003.6+ KB

# %% [markdown]
# #### 3.2  Dealing with Null values

# %% [markdown]
# #### A) price

# %%
# Since the 'price' is the var we want to predict, rows without price are no longer necessary.
df["price"].isnull().sum() #output: 150
df = df.dropna(subset=["price"])

# %%
df["price"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum() #return series of columns with respective number of null values
# Out:
# marketplace_listing_title        0
# vehicle_exterior_color         112
# vehicle_fuel_type             1405
# vehicle_make_display_name        0
# vehicle_model_display_name     389
# vehicle_transmission_type       14
# kms                             35
# price                            0
# state                            7
# year                             0
# dtype: int64

# %%
#heatmap to identify nulll values using graph
sns.heatmap(df.isnull(),yticklabels=False,cbar=True,cmap='Accent')
# Out:
# <Axes: >

# %% [markdown]
# #### B) vehicle_exterior_color

# %%
top_ext_colors = df["vehicle_exterior_color"].value_counts().tail(10)
sns.barplot(x=top_ext_colors.index, y=top_ext_colors.values)
plt.xticks(rotation = 45)
plt.show()

#Vehicle Exterior Color: Since there are 112 null values, those values will be filled by the mode ('white')
most_common_color = df["vehicle_exterior_color"].mode()[0]
print(most_common_color)
df["vehicle_exterior_color"] = df["vehicle_exterior_color"].fillna(most_common_color)

#Also, 'off_white', 'other' and 'tan' colors will be replaced by 'white'.
df["vehicle_exterior_color"] = df["vehicle_exterior_color"].replace(['off_white','other','tan'],'white')
# Out:
# white

# %% [markdown]
# #### C) vehicle_fuel_type

# %%
#Since this var contains the greatest amount of null values, 
#let's dive into them, merging null values with 'OTHER'
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

df["vehicle_fuel_type"] = df["vehicle_fuel_type"].fillna("OTHER")
fuel_types_brand = pd.crosstab(
    df["vehicle_make_display_name"],
    df["vehicle_fuel_type"] == 'OTHER'
)
print(fuel_types_brand)
# Out:
# vehicle_fuel_type                 False  True
# vehicle_make_display_name
# 1990 v8 5 speed manual commodore      1      0
# 2023                                  1      0
# Abarth                                3      0
# Alfa Romeo                           17      2
# All                                   1      0
# Astra                                 1      0
# Audi                                238     27
# Audi Q3 2.0T petrol AWD Quattro       1      0
# Austin                                3      0
# BMW                                 407     59
# BYD                                   5      1
# Bedford                               1      0
# Bentley                               2      2
# Bflpgwagon                            0      1
# Buick                                 1      0
# Byd                                   1      0
# CHEAP CAR RENTAL FROM $150            0      1
# Cadillac                              2      0
# ...

# %%
#since 'Petrol' and 'Gasoline' is the same, we merge both categories in just one.
df["vehicle_fuel_type"] = df["vehicle_fuel_type"].replace(['GASOLINE'],'PETROL')

#Also, replace the 'plugin_hybrid' by 'hybrid'
df["vehicle_fuel_type"] = df["vehicle_fuel_type"].replace(['PLUGIN_HYBRID'],'HYBRID')

#'Flex' type is not representative in the dataset (18 values). We drop it.
df = df[df['vehicle_fuel_type'] != 'FLEX']

fuel_type = df["vehicle_fuel_type"].value_counts()
print(fuel_type)
# Out:
# vehicle_fuel_type
# PETROL      7147
# DIESEL      2827
# OTHER       1464
# HYBRID       319
# ELECTRIC      42
# Name: count, dtype: int64

# %%
df[df['vehicle_fuel_type'] == 'OTHER'].head()
# Out:
#       marketplace_listing_title vehicle_exterior_color vehicle_fuel_type  \
# 50    1992 Toyota Troop carrier                  white             OTHER
# 61        2011 Holden Commodore                  white             OTHER
# 63              2002 Holden Ute                   gold             OTHER
# 75              2026 Mazda RX-8                 silver             OTHER
# 76  2009 Toyota Landcruiser 200                  white             OTHER
#
#    vehicle_make_display_name vehicle_model_display_name  \
# 50                    Toyota              troop carrier
# 61                    Holden                  Commodore
# 63                    Holden                        Ute
# 75                     Mazda                       RX-8
# 76                    Toyota            Landcruiser 200
#
#    vehicle_transmission_type     kms  price state  year
# 50                    MANUAL  525000  13000   QLD  1992
# 61                 AUTOMATIC  184000  10000   QLD  2011
# ...

# %% [markdown]
# #### D) vehicle_model_display_name

# %%
#checking null values
df[df["vehicle_model_display_name"].isna()].head(10)
#As we can see, the most majority of the model_display_name is extractable  from the column 'marketplace_listing_title'
#After the second [space] in the string.
# Out:
#                      marketplace_listing_title vehicle_exterior_color  \
# 48                           2010 BMW series 3                   blue
# 62   2012 Volkswagen [hidden information]79079                   blue
# 88         2003 MINI [hidden information]99743                 silver
# 105                         2015 Toyota kluger                 silver
# 115   2022 Ssangyong [hidden information]25819               charcoal
# 152                         2013 Toyota estima                   grey
# 156                           2015 Peugeot 508                  white
# 178                   2015 BMW 631048834020699                 silver
# 188                               2020 LDV g10                  white
# 207                         2014 Toyota kluger                   gold
#
#     vehicle_fuel_type vehicle_make_display_name vehicle_model_display_name  \
# 48             DIESEL                       BMW                        NaN
# ...

# %%
#extracting model
model = (df["marketplace_listing_title"].str.split(r"\s+", n=2).str[2])
#Replacing in the proper dataset 
df.loc[
    df["vehicle_model_display_name"].isna(),
    "vehicle_model_display_name"
] = model

df['vehicle_model_display_name'].isnull().sum()
#Doing this the null values is now zero, however, we have to treat the outliers and values which don't have sense
#in next steps.
# Out:
# 0

# %% [markdown]
# #### E) Kilometers

# %%
#Since there are only 35 null values it looks like it is not necessary to treat this values.
#Dropping them seems to be the best approach

df = df.dropna(subset=["kms"])
df['kms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### F) vehicle_transmission_type

# %%
#checking null values
df['kms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### G) State

# %%
#Same approach as Kms since there are only 7 null values
df[df["state"].isna()]
df = df.dropna(subset=["state"])
df['state'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Doble-checking Null Values after treating them

# %%
#heatmap to identify nulll values using graph
print(df.isnull().sum())
sns.heatmap(df.isnull(),yticklabels=False,cbar=True,cmap='Accent')
plt.show()
print(df.shape)
# Out:
# marketplace_listing_title     0
# vehicle_exterior_color        0
# vehicle_fuel_type             0
# vehicle_make_display_name     0
# vehicle_model_display_name    0
# vehicle_transmission_type     0
# kms                           0
# price                         0
# state                         0
# year                          0
# dtype: int64
# (11757, 10)

# %% [markdown]
# ## 4. Dealing with Outliers

# %% [markdown]
# #### A) Price

# %%
plt.boxplot(df['price'], vert=False)
df[df['price'] > 250000].head(5)
# Out:
#       marketplace_listing_title vehicle_exterior_color vehicle_fuel_type  \
# 550          2005 Nissan Patrol                   gold            DIESEL
# 1371    1999 Toyota Landcruiser                    red            PETROL
# 1532       2002 Subaru Libertty                 silver             OTHER
# 1538  1989 Land Rover Discovery                  white            PETROL
# 1651        1973 Toyota Corolla                  green             OTHER
#
#      vehicle_make_display_name vehicle_model_display_name  \
# 550                     Nissan                     Patrol
# 1371                    Toyota                Landcruiser
# 1532                    Subaru                   libertty
# 1538                Land Rover                  Discovery
# 1651                    Toyota                    Corolla
#
#      vehicle_transmission_type     kms    price state  year
# 550                  AUTOMATIC  240000  1234567    WA  2005
# ...

# %%
#As it is shown above, there are outliers where prices are too high and too low. Let's calculate IQR
print(df['price'].describe())
#IQR Method TO Detect Outliers in 'Price'
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_price = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
print(f'Number of outliers in price: {outliers_price.shape[0]}')
print('lower bound: '+ str(lower_bound) ,'upper bound: '+ str(upper_bound))
print(outliers_price.describe())

# The results show a negative lower bound and an upper bound of $50,050. Any values above the upper bound should be dropped as outliers.
# Although the lower bound is negative (meaning all low values would be retained), 
# this does not reflect a real-world scenario: car prices cannot be negative, and
# very low values often indicate wrecked vehicles or data entry errors. Similarly, extremely high prices are not representative of the typical market
# and should also be treated as outliers.
# Out:
# count          11757.0
# mean      22020.593859
# std      140115.708425
# min                1.0
# 25%             5800.0
# 50%            12000.0
# 75%            23498.0
# max          9999999.0
# Name: price, dtype: Float64
# Number of outliers in price: 765
# lower bound: -20747.0 upper bound: 50045.0
#                  kms          price         year
# count          765.0          765.0   765.000000
# mean   108364.806536  135646.875817  2012.853595
# std    152391.976727  535182.511851    16.013885
# min            300.0        50500.0  1926.000000
# 25%          28000.0        59000.0  2012.000000
# 50%          65137.0        70000.0  2019.000000
# 75%         123456.0       100000.0  2022.000000
# max        1000000.0      9999999.0  2026.000000

# %%
# Define bounds
lower_bound = 2500 #Setting $2.500 as lower bound (pragmatical approach)
upper_bounds = np.arange(20000, 600001, 15000) #Testing what should be the correct upper_bound


counts = []
variance_reductions = []


original_variance = df[df['price'] > 2500]['price'].var()

for upper_bound in upper_bounds:
    # Count of observations within both bounds
    count = ((df['price'] >= lower_bound) & (df['price'] <= upper_bound)).sum()
    counts.append(count)
    
    # Variance of data within both bounds
    filtered_data = df[(df['price'] >= lower_bound) & (df['price'] <= upper_bound)]['price']
    new_variance = filtered_data.var()
    
    # Percentage variance reduction
    var_reduction = ((original_variance - new_variance) / original_variance) * 100
    variance_reductions.append(var_reduction)




# Create the Pareto chart
fig, ax1 = plt.subplots(figsize=(14, 6))

# Plot bars (counts)
color = 'tab:blue'
ax1.set_xlabel('Upper Bound Price Threshold', fontsize=12)
ax1.set_ylabel('Cumulative Count of Observations', color=color, fontsize=12)
ax1.bar(upper_bounds, counts, width=800, color=color, alpha=0.6)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(axis='y', alpha=0.3)

# Create secondary y-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Variance Reduction (%)', color=color, fontsize=12)
ax2.plot(upper_bounds, variance_reductions, color=color, linewidth=2, marker='o', markersize=2)
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title(f'Pareto Chart: Trade-off Between Data Retention and Variance Reduction\n(Lower Bound = ${lower_bound:,.0f})', 
          fontsize=14, fontweight='bold')
fig.tight_layout()
plt.show()

# Print some key thresholds
print(f"Total observations: {len(df)}")
print(f"Lower bound: ${lower_bound:,.0f}")
print(f"\nSample thresholds:")
for i in [0, len(upper_bounds)//4, len(upper_bounds)//2, 3*len(upper_bounds)//4, -1]:
    print(f"Upper bound ${upper_bounds[i]:,.0f}: {counts[i]} obs ({counts[i]/len(df)*100:.2f}%), Variance reduction: {variance_reductions[i]:.2f}%")
# Out:
# Total observations: 11757
# Lower bound: $2,500
#
# Sample thresholds:
# Upper bound $20,000: 7274 obs (61.87%), Variance reduction: 99.88%
# Upper bound $155,000: 10667 obs (90.73%), Variance reduction: 98.12%
# Upper bound $305,000: 10695 obs (90.97%), Variance reduction: 97.70%
# Upper bound $455,000: 10696 obs (90.98%), Variance reduction: 97.65%
# Upper bound $590,000: 10698 obs (90.99%), Variance reduction: 97.43%

# %%
# Variance stops increasing significantly above $200,000.
# Upper bound set at $200,000 for optimal statistical benefit.
total_rows = len(df)
upper_bound = 200000
removed_rows = len(df[(df["price"] < lower_bound) | (df["price"] > upper_bound)]) 


percentage_removed = removed_rows / total_rows * 100


var_before = df["price"].var()
df_filtered = df_filtered = df[
    (df["price"] >= lower_bound) & (df["price"] <= upper_bound)
]
var_after = df_filtered["price"].var()
variance_reduction = (var_before - var_after) / var_before * 100

print('The applied thresholds removed '+str(round(percentage_removed, 2))+'% of *observations* while reducing *price variance* by '+str(round(variance_reduction, 2))+'%')

df = df[
    (df["price"] >= lower_bound) & (df["price"] <= upper_bound)]
df.reset_index(drop=True, inplace=True)

plt.boxplot(df['price'], vert=False)
plt.show()
# Out:
# The applied thresholds removed 9.13% of *observations* while reducing *price variance* by 97.73%

# %%
print(df["price"].describe())
sns.histplot(df["price"], bins=80, kde=True)
plt.show()
# Out:
# count         10684.0
# mean     19972.651254
# std      21132.921324
# min            2500.0
# 25%            7000.0
# 50%           13099.5
# 75%           24999.0
# max          199888.0
# Name: price, dtype: Float64

# %% [markdown]
# ### B) vehicle_make_display_name

# %%
# Get value counts
counts = df['vehicle_make_display_name'].value_counts()


#1. Setting upper cases for all values
df['vehicle_make_display_name'] = df['vehicle_make_display_name'].str.upper()
df['vehicle_make_display_name'].value_counts()
#2. Identifying brands with more than one word (ASTON MARTIN, LAND ROVER, etc.)
multi_word_brands = [
    'ASTON MARTIN',
    'ALFA ROMEO',
    'LAND ROVER',
    'MERCEDES BENZ',
    'ROLLS ROYCE'
]
#3. Transforming those brands without space in the dataset (ASTON-MARTIN, LAND-ROVER, etc.)
df['vehicle_make_display_name'] = df['vehicle_make_display_name'].apply(
    lambda x: x.replace(' ', '-',1) if x in multi_word_brands else x
)
#4. Extracting only the first word in the column ensuring transformation of data errors.
df['vehicle_make_display_name'] = (df["vehicle_make_display_name"].str.split(r"\s+", n=1).str[0])

#Double-checking changes
df['vehicle_make_display_name'].value_counts()
# Out:
# vehicle_make_display_name
# TOYOTA                   1879
# HOLDEN                    986
# FORD                      930
# NISSAN                    768
# MAZDA                     656
# HYUNDAI                   627
# VOLKSWAGEN                555
# MITSUBISHI                553
# MERCEDES-BENZ             448
# BMW                       434
# SUBARU                    393
# HONDA                     363
# AUDI                      255
# KIA                       245
# JEEP                      193
# SUZUKI                    161
# ISUZU                     125
# LAND-ROVER                108
# LEXUS                      96
# RENAULT                    85
# MINI                       62
# VOLVO                      56
# MG                         51
# PEUGEOT                    41
# CHEVROLET                  40
# HINO                       37
# ŠKODA                      34
# CHRYSLER                   34
# LDV                        34
# PORSCHE                    29
# ...

# %% [markdown]
# #### Brands with fewer than 10 samples were removed from the dataset to ensure statistical reliability. With 10,000+ total observations, these rare brands represent less than 0.1% of the data but introduce significant noise and variance. Machine learning models require sufficient examples per category to learn meaningful patterns; brands with <10 samples provide insufficient training data for reliable price predictions. This filtering improves model robustness while retaining 99%+ of the dataset.

# %%
brand_counts = df['vehicle_make_display_name'].value_counts()
rare_brands = brand_counts[brand_counts < 10].index
df = df[~df['vehicle_make_display_name'].isin(rare_brands)]

#Also, I've found the brand 'GREAT' represents 'GWM' brand
df['vehicle_make_display_name'] = df['vehicle_make_display_name'].replace('GREAT','GWM')

# %%
df['vehicle_make_display_name'].value_counts()
sns.countplot(data=df, y="vehicle_make_display_name", order=df["vehicle_make_display_name"].value_counts().index)
plt.yticks(fontsize=6)
plt.show()
#It seems like all the brands are properly cleaned and good for ML purposes.

# %% [markdown]
# ### C) vehicle_model_display_name

# %%
# Get value counts
counts = df['vehicle_model_display_name'].value_counts()
print('Quantity of unique models values: '+str(counts[counts < 2].sum()))
# Out:
# Quantity of unique models values: 1861

# %%
df['vehicle_model_display_name'].value_counts().tail(100)
# Out:
# vehicle_model_display_name
# corolla cross                                                                            1
# 6 mps luxury                                                                             1
# xr-5                                                                                     1
# fuso canter                                                                              1
# npr premium                                                                              1
# city sedan                                                                               1
# lancer vrx                                                                               1
# navara st-x d40                                                                          1
# c250 avantagrade                                                                         1
# e240 e-class elegance w210                                                               1
# ...

# %% [markdown]
# #### This feature appears to be the messiest in the dataset, making it difficult to identify a clear pattern for removing or replacing values.
#
# #### A dimension table (LLMs help) with unique models cars in Australia was created.
# #### Let's match these values with the column 'vehicle_model_display_name'

# %%
# 1. Upper cases
df['vehicle_model_display_name'] = df['vehicle_model_display_name'].str.upper()
df['vehicle_make_display_name'] = df['vehicle_make_display_name'].str.upper()

# 2. Load dimension table
dim_table = pd.read_csv("data/dimension_table_car_models.csv")
dim_table['make_vehicle'] = dim_table['make_vehicle'].str.upper()
dim_table['model_vehicle'] = dim_table['model_vehicle'].str.upper()

# 3. Create a dictionary: {MAKE: [list of models sorted by length]}
make_models_dict = {}
for make in dim_table['make_vehicle'].unique():
    models = dim_table[dim_table['make_vehicle'] == make]['model_vehicle'].unique()
    # Sort by length (longest first) to match longer patterns first
    make_models_dict[make] = sorted(models, key=len, reverse=True)

# 4. Match models only within the correct make
def extract_model(row):
    make = row['vehicle_make_display_name']
    model_text = row['vehicle_model_display_name']
    
    # If make exists in our dictionary
    if make in make_models_dict:
        # Try to find a matching model for this make
        for model in make_models_dict[make]:
            if model in model_text:
                return model
    
    # If no match found, return original
    return model_text

df['vehicle_model_display_name'] = df.apply(extract_model, axis=1)

#5. dropping rows with any [hidden info] or phone number (doesn't specify the actual model)
df = df[~df['vehicle_model_display_name'].str.contains(r'\[', na=False)]  # Remove rows with '['
df = df[~df['vehicle_model_display_name'].str.match(r'^\d+$', na=False)]  # Remove rows with only numbers

# %%
counts = df[['vehicle_model_display_name']].value_counts()
print(counts.tail(15))
print('Quantity of unique models values: '+str(counts[counts < 2].sum()))
# Out:
# vehicle_model_display_name
# FD HINO                       1
# FEA21                         1
# FM10.0                        1
# FG / FPV                      1
# FG CRANE TRUCK                1
# FGX                           1
# FIAT SCUDO                    1
# FIELDER HYBRID                1
# FIGHTER                       1
# FIGHTER 2427                  1
# FIT GP5                       1
# FLUENCE                       1
# FM                            1
# FM 13  460HP PRIME MOVER      1
# 其他                            1
# Name: count, dtype: int64
# Quantity of unique models values: 722

# %% [markdown]
# #### With this approach I've reduced from 1861 messy values to 722.

# %%
#Proceeding to drop models with only one registration
model_counts = df['vehicle_model_display_name'].value_counts()
rare_models = model_counts[model_counts < 2].index
df = df[~df['vehicle_model_display_name'].isin(rare_models)]
df.shape
# Out:
# (9108, 10)

# %%
df.tail()
# Out:
#                                marketplace_listing_title  \
# 10679            2019 Ford RANGER WILDTRAK PX MKlll AUTO
# 10680                           2002 Mercedes-Benz Sedan
# 10681                                2021 Nissan Qashqai
# 10682  2013 Hyundai 2013 Hyundai ix35 LM3 Elite Wagon...
# 10683                             2015 Mitsubishi Lancer
#
#       vehicle_exterior_color vehicle_fuel_type vehicle_make_display_name  \
# 10679                 silver            DIESEL                      FORD
# 10680                  white            PETROL             MERCEDES-BENZ
# 10681                   grey            PETROL                    NISSAN
# 10682                   grey            PETROL                   HYUNDAI
# 10683                  white            PETROL                MITSUBISHI
#
#       vehicle_model_display_name vehicle_transmission_type     kms  price  \
# 10679                     RANGER                 AUTOMATIC  247000  27999
# ...

# %%
df.to_csv("cleaned_car_data.csv", index=False)
